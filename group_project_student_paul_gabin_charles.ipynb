# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly.express
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import plotly.express as px


stu = pd.read_csv('dataset.csv')

X = stu.drop('Target', axis=1)
y = stu['Target']

scaler = StandardScaler()
X_std = scaler.fit_transform(X)

pca = PCA()
X_pca = pca.fit_transform(X_std)

explained_variance = pca.explained_variance_ratio_
cumulative_explained_variance = explained_variance.cumsum()

plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.show()

n_components = 34

pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_std)

columns = [f'PC{i}' for i in range(1, n_components + 1)]
stu_pca = pd.DataFrame(data=X_pca, columns=columns)
stu_pca['Target'] = y

# %%
pip install warnings
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement warnings (from versions: none)
# ERROR: No matching distribution found for warnings

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn  as sns
import sklearn
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
stu
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                 8                  5       2
# 1                  1                 6                  1      11
# 2                  1                 1                  5       5
# 3                  1                 8                  2      15
# 4                  2                12                  1       3
# ...              ...               ...                ...     ...
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                              1                       1            1
# ...

# %% [markdown]
# Pour voir les significations des chiffres pour les différentes variables : ouvrez le fichier Variables Names.xlsx sur GitHub.

# %% [markdown]
# ## *Basic Pandas*

# %%
#This command shows the first/last 5 rows of given dataset:
stu.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %%
#This command shows the last 5 rows of given dataset:
stu.tail()
# Out:
#       Marital status  Application mode  Application order  Course  \
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       Daytime/evening attendance  Previous qualification  Nacionality  \
# 4419                           1                       1            1
# 4420                           1                       1           19
# 4421                           1                       1            1
# 4422                           1                       1            1
# 4423                           1                       1            9
#
#       Mother's qualification  Father's qualification  Mother's occupation  \
# ...

# %%
#This command shows the order pair of given dataset:
stu.shape
# Out:
# (4424, 35)

# %% [markdown]
# The explaination of this line is : 4424 datas and 35 variables

# %%
#This command gives the duplicated values  of given dataset:
stu.duplicated().sum()
# Out:
# 0

# %%
#This command gives the missing values of given dataset:

stu.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# ...

# %%
#This command counts the values of target column:
stu.Target.value_counts()
# Out:
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: Target, dtype: int64

# %%
#This command groups the target column ("is_claim") into all other columns.
#Following cammand shows the relationship between target and other column:

gp = stu.groupby('Target').count()
gp
# Out:
#           Marital status  Application mode  Application order  Course  \
# Target
# Dropout             1421              1421               1421    1421
# Enrolled             794               794                794     794
# Graduate            2209              2209               2209    2209
#
#           Daytime/evening attendance  Previous qualification  Nacionality  \
# Target
# Dropout                         1421                    1421         1421
# Enrolled                         794                     794          794
# Graduate                        2209                    2209         2209
#
#           Mother's qualification  Father's qualification  Mother's occupation  \
# Target
# Dropout                     1421                    1421                 1421
# Enrolled                     794                     794                  794
# Graduate                    2209                    2209                 2209
#
# ...

# %% [markdown]
# ## *Visualization*

# %%
#Tis command is used to draw a catplot between target column and other columns:

num_col = ['Inflation rate','Unemployment rate','GDP']
for i in num_col:
  sns.catplot(x= i, y ="Target", data =stu, kind = "box", aspect = 2)
  plt.title("Boxplot for Target vs Population")
  plt.show()

# %%
#This command is used to draw a count plot of Inflation rate column:
#This is useful for visualizing the distribution of values and identifying trends or dominant values in the various columns.

plt.figure(figsize = (25,5))
sns.countplot(x='Inflation rate', data=stu)
plt.xlabel('Inflation Rate')
plt.ylabel('Count')
plt.title('Distribution of Inflation Rate')
plt.show()

# %%
#This command is used to draw a count plot of Unemployment rate column:

plt.figure(figsize = (25,5))
sns.countplot(x='Unemployment rate', data=stu)
plt.xlabel('Unemployment rate')
plt.ylabel('Count')
plt.title('Distribution of Unemployment rate')
plt.show()

# %%
#This command is used to draw a count plot of GDP column:

plt.figure(figsize = (25,5))
sns.countplot(x='GDP', data=stu)
plt.xlabel('GDP')
plt.ylabel('Count')
plt.title('Distribution of GDP')
plt.show()

# %%
#This command is used to draw a count plot of Target column:

plt.figure(figsize = (10,5))
sns.countplot(x='Target', data=stu)
plt.xlabel('Target')
plt.ylabel('Count')
plt.title('Distribution of Target')
plt.show()

# %%
#This command is used to draw correlation matrix:
#Here we remove the last non-number column to create the correlation matrix
selected_columns = stu.iloc[:, :-1]

correlation_matrix = selected_columns.corr()
print(correlation_matrix)
# Out:
#                                                 Marital status  \
# Marital status                                        1.000000
# Application mode                                      0.224855
# Application order                                    -0.125854
# Course                                                0.018925
# Daytime/evening attendance                           -0.274939
# Previous qualification                                0.120925
# Nacionality                                          -0.020722
# Mother's qualification                                0.185522
# Father's qualification                                0.128326
# Mother's occupation                                   0.069734
# Father's occupation                                   0.024351
# Displaced                                            -0.234886
# Educational special needs                            -0.028343
# Debtor                                                0.034304
# ...

# %%
#This command is used to draw a heatmap of correlation matrix:
plt.figure(figsize = (40,20))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title('Correlation Matrix of Iris Dataset')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

stu['Target'] = stu['Target'].map({
    'Dropout':0,
    'Enrolled':1,
    'Graduate':2
})

correlations = stu.corr()['Target']
top_10_features = correlations.abs().nlargest(10).index
top_10_corr_values = correlations[top_10_features]

plt.figure(figsize=(10, 11))
plt.bar(top_10_features, top_10_corr_values)
plt.xlabel('Features')
plt.ylabel('Correlation with Target')
plt.title('Top 10 Features with Highest Correlation to Target')
plt.xticks(rotation=45)
plt.show()

# %%
new_data = stu.copy()
new_data = new_data.drop(columns=['Nacionality', 
                                  'Mother\'s qualification', 
                                  'Father\'s qualification', 
                                  'Educational special needs', 
                                  'International', 
                                  'Curricular units 1st sem (without evaluations)',
                                  'Unemployment rate', 
                                  'Inflation rate'], axis=1)
new_data.info()
new_data['Target'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 27 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Mother's occupation                             4424 non-null   int64
#  7   Father's occupation                             4424 non-null   int64
#  8   Displaced                                       4424 non-null   int64
# ...

# %%
x = new_data['Target'].value_counts().index
y = new_data['Target'].value_counts().values

df = pd.DataFrame({
    'Target': x,
    'Count_T' : y
})

fig = px.pie(df,
             names ='Target', 
             values ='Count_T',
            title='How many dropouts, enrolled & graduates are there in Target column')

fig.update_traces(labels=['Graduate','Dropout','Enrolled'], hole=0.4,textinfo='value+label', pull=[0,0.2,0.1])
fig.show()

# %%
px.histogram(new_data['Age at enrollment'], x='Age at enrollment',color_discrete_sequence=['lightblue'])

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Target', y='Age at enrollment', data=new_data)
plt.xlabel('Target')
plt.ylabel('Age at enrollment')
plt.title('Relationship between Age and Target')
plt.show()

# %% [markdown]
# 2 - graduated
# 1 - enrolled
# 0 - dropout

# %% [markdown]
# ## *Label Encoding at Target column, Split data into train and test model*

# %%
#import libraries  accuracy and test-train slipt:

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
# This command is used to Split dataset into X and y:

X = stu.drop(columns= ['Target'])
y = stu[['Target']]

# %%
#This command is used to show the order pair of X and y:

print("X shape is: ",X.shape)
print("y shape is: ",y.shape)
# Out:
# X shape is:  (4424, 34)
# y shape is:  (4424, 1)

# %%
#This command split given dataset into test and train:

X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.20)

# %%
#This command shows the order pair of test and train

print("shape of X_train: ", X_train.shape)
print("shape of Y_train: ", Y_train.shape)
print("shape of X_test: ", X_test.shape)
print("shape of Y_test: ", Y_test.shape)
# Out:
# shape of X_train:  (3539, 34)
# shape of Y_train:  (3539, 1)
# shape of X_test:  (885, 34)
# shape of Y_test:  (885, 1)

# %% [markdown]
# ## *Classification Model --> "Logistic Regression"*

# %%
#Import Logistic Regression libraries:

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
# Fit the Model:

model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
#Calculate accuracy score:

y_pred = model.predict(X_test)
score = accuracy_score(Y_test, y_pred)
accuracy = score*100
print(accuracy)
# Out:
# 76.7231638418079

# %%
# This command is used to draw confussion matrix:

from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)
print("Confusion Matrix")
cm_lr = confusion_matrix(Y_test, y_pred)
print(cm_lr)
# Out:
# Confusion Matrix
# [[207  22  45]
#  [ 42  48  73]
#  [ 10  14 424]]

# %%
# This command is used to draw a heatmap of confussion matrix:

plt.figure(figsize = (6, 4))
sns.heatmap(cm_lr, annot = True, fmt = 'd', cmap = 'Blues', cbar = False, annot_kws = {'size' : 14})
plt.xlabel('Predicted Labels', fontsize = 14)
plt.ylabel('True Labels', fontsize = 14)
plt.title('Confusion Matrix', fontsize = 16)
plt.show()

# %% [markdown]
# 2 - graduated
# 1 - enrolled
# 0 - dropout

# %%
#This command is used to verify the model based on given dataset:

X_test1 = X_test.values
y_test1 = Y_test.values
y_pred = str(model.predict([X_test1[16]]))
print(type(y_pred))

if y_pred == "[0]":
  print("Dropout")
elif y_pred == "[1]":
  print("Enrolled")
elif y_pred == "[2]":
  print("Graduate")
# Out:
# <class 'str'>
# Graduate

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Fit the Model:
model.fit(X_train, Y_train)

# Calculate accuracy score:
y_pred = model.predict(X_test)
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate precision:
precision = precision_score(Y_test, y_pred, average='weighted')
print("Precision:", precision)

# Calculate recall:
recall = recall_score(Y_test, y_pred, average='weighted')
print("Recall:", recall)

# Calculate F1-score:
f1 = f1_score(Y_test, y_pred, average='weighted')
print("F1-score:", f1)
# Out:
# Accuracy: 0.7672316384180791
# Precision: 0.7486962924075939
# Recall: 0.7672316384180791
# F1-score: 0.7456713636265866

# %% [markdown]
# ## *Classification Model --> "Decision Tree"*

# %%
#Import decesion tree classifier library and develop the model:

from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()

# %%
# Fit model:
dtc.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
#This command is used to calculate accuracy of the model:

y_pred = dtc.predict(X_test)
score = accuracy_score(Y_test, y_pred)
accuracy = score*100
print(accuracy)
# Out:
# 66.55367231638418

# %%
# This command is used to draw confussion matrix:

from sklearn.metrics import confusion_matrix
y_pred = dtc.predict(X_test)
print("Confusion Matrix")
cm_dtc = confusion_matrix(Y_test, y_pred)
print(cm_dtc)
# Out:
# Confusion Matrix
# [[189  37  48]
#  [ 45  57  61]
#  [ 46  59 343]]

# %%
# This command is used to draw a heatmap of confussion matrix:

plt.figure(figsize = (6, 4))
sns.heatmap(cm_dtc, annot = True, fmt = 'd', cmap = 'Blues', cbar = False, annot_kws = {'size' : 14})
plt.xlabel('Predicted Labels', fontsize = 14)
plt.ylabel('True Labels', fontsize = 14)
plt.title('Confusion Matrix', fontsize = 16)
plt.show()

# %% [markdown]
# ## *Classification Model --> "Support Vector Machine (SVM)"*

# %%
#Import support vector machine library and develop the model:

from sklearn.svm import SVC
sss = SVC()

# %%
#Fit model:
sss.fit(X_train, Y_train)
# Out:
# SVC()

# %%
#This command is used to calculate accuracy of the model:

y_pred = sss.predict(X_test)
score = accuracy_score(Y_test, y_pred)
accuracy = score*100
print(accuracy)
# Out:
# 74.46327683615819

# %%
# This command is used to draw confussion matrix:

from sklearn.metrics import confusion_matrix
y_pred = sss.predict(X_test)
print("Confusion Matrix")
cm_sss = confusion_matrix(Y_test, y_pred)
print(cm_sss)
# Out:
# Confusion Matrix
# [[187  21  66]
#  [ 36  42  85]
#  [  9   9 430]]

# %%
# This command is used to draw a heatmap of confussion matrix:

plt.figure(figsize = (6, 4))
sns.heatmap(cm_sss, annot = True, fmt = 'd', cmap = 'Blues', cbar = False, annot_kws = {'size' : 14})
plt.xlabel('Predicted Labels', fontsize = 14)
plt.ylabel('True Labels', fontsize = 14)
plt.title('Confusion Matrix', fontsize = 16)
plt.show()

# %%
# SVM
sss.fit(X_train, Y_train)
y_pred_svm = sss.predict(X_test)
accuracy_svm = accuracy_score(Y_test, y_pred_svm)
precision_svm = precision_score(Y_test, y_pred_svm, average='weighted')
recall_svm = recall_score(Y_test, y_pred_svm, average='weighted')
f1_svm = f1_score(Y_test, y_pred_svm, average='weighted')

# Decision Tree
dtc.fit(X_train, Y_train)
y_pred_decision_tree = dtc.predict(X_test)
accuracy_decision_tree = accuracy_score(Y_test, y_pred_decision_tree)
precision_decision_tree = precision_score(Y_test, y_pred_decision_tree, average='weighted')
recall_decision_tree = recall_score(Y_test, y_pred_decision_tree, average='weighted')
f1_decision_tree = f1_score(Y_test, y_pred_decision_tree, average='weighted')

# Logistic Regression
model.fit(X_train, Y_train)
y_pred_logistic_regression = model.predict(X_test)
accuracy_logistic_regression = accuracy_score(Y_test, y_pred_logistic_regression)
precision_logistic_regression = precision_score(Y_test, y_pred_logistic_regression, average='weighted')
recall_logistic_regression = recall_score(Y_test, y_pred_logistic_regression, average='weighted')
f1_logistic_regression = f1_score(Y_test, y_pred_logistic_regression, average='weighted')

print("SVM Metrics:")
print("Accuracy:", accuracy_svm)
print("Precision:", precision_svm)
print("Recall:", recall_svm)
print("F1-score:", f1_svm)
print()

print("Decision Tree Metrics:")
print("Accuracy:", accuracy_decision_tree)
print("Precision:", precision_decision_tree)
print("Recall:", recall_decision_tree)
print("F1-score:", f1_decision_tree)
print()

print("Logistic Regression Metrics:")
print("Accuracy:", accuracy_logistic_regression)
print("Precision:", precision_logistic_regression)
print("Recall:", recall_logistic_regression)
print("F1-score:", f1_logistic_regression)
# Out:
# SVM Metrics:
# Accuracy: 0.7446327683615819
# Precision: 0.731641860643431
# Recall: 0.7446327683615819
# F1-score: 0.7177484040962169
#
# Decision Tree Metrics:
# Accuracy: 0.6644067796610169
# Precision: 0.6627616194972149
# Recall: 0.6644067796610169
# F1-score: 0.6635550376069254
#
# Logistic Regression Metrics:
# Accuracy: 0.7672316384180791
# Precision: 0.7486962924075939
# Recall: 0.7672316384180791
# F1-score: 0.7456713636265866

# %% [markdown]
# The three models (SVM, Decision Tree, Logistic Regression) show relatively similar performances in terms of accuracy, precision, recall, and F1-score. Logistic Regression seems to have a slight edge in terms of accuracy and recall.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = pd.read_csv("dataset.csv")


course_mapping = {
    1: "Biofuel Production Technologies",
    2: "Animation and Multimedia Design",
    3: "Social Service (evening attendance)",
    4: "Agronomy",
    5: "Communication Design",
    6: "Veterinary Nursing",
    7: "Informatics Engineering",
    8: "Equiniculture",
    9: "Management",
    10: "Social Service",
    11: "Tourism",
    12: "Nursing",
    13: "Oral Hygiene",
    14: "Advertising and Marketing Management",
    15: "Journalism and Communication",
    16: "Basic Education",
    17: "Management (evening attendance)"
}

data['Course'] = data['Course'].map(course_mapping)


plt.figure(figsize=(12, 8))
sns.countplot(x='Course', hue='Target', data=data, palette='Set1')


plt.xlabel('Course')
plt.ylabel('Number of Students')
plt.title('Number of Students by Course and Target')


plt.legend(title='Target', loc='upper right')


plt.xticks(rotation=45, ha='right')  
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

stu["Father's occupation"] = stu["Father's occupation"].astype(str)

counts = stu.groupby(["Father's occupation", 'Target']).size().reset_index(name='Count')

plt.figure(figsize=(15, 8))
sns.barplot(x='Count', y="Father's occupation", hue='Target', data=counts, palette='Set1', orient='horizontal')

plt.xlabel('Number of Students')
plt.ylabel("Father's Profession")
plt.title("Number of Students by Father's Profession and Target")

plt.legend(title='Target', loc='upper right', labels=['Enrolled', 'Graduated', 'Dropout'])

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
 
stu['Tuition Group'] = stu['Tuition fees up to date'].map({0: 'Not Up to Date', 1: 'Up to Date'})
 
nombre_etudiants_par_groupe = stu.groupby(['Target', 'Tuition Group']).size().unstack()
 
fig, ax = plt.subplots()
bar_plot = nombre_etudiants_par_groupe.plot(kind='bar', stacked=True, ax=ax, color=['navy', 'skyblue'])
 
ax.set_xlabel('Category')
ax.set_ylabel('Number of students')
ax.set_title('Number of students by category and status of tuition fees')
 
ax.set_xticklabels(['Dropout', 'Enrolled', 'Graduated'], rotation=0)
 
ax.legend(title='Tuition Fees Up to Date', loc='upper right')
 
for p in bar_plot.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()
    ax.text(x + width/2, y + height/2, f'{int(height)}', ha='center', va='center', fontsize=8, color='white')
 
plt.show()
